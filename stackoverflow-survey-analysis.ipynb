# %%
import pandas as pd

# %%
df = pd.read_csv('./data/survey_results_public.csv')

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
df.shape #attribute instead of method
# Out:
# (65437, 114)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
schema_df = pd.read_csv('./data/survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# ...

# %%
df.head()

# %%
df.tail(2)

# %%
df = pd.read_csv('./data/survey_results_public.csv')

# %%
df.shape

# %%
df.head()

# %%
df.columns

# %%
df['RemoteWork']

# %%
#value count methode
df['RemoteWork'].value_counts()

# %%
df.loc[0, 'RemoteWork'] #argument1: label in rows, argument2: values in columns

# %%
df.loc[[0,3,200], 'RemoteWork']

# %%
df.loc[0:3, 'RemoteWork':'LearnCode'] #stop inclusive

# %%
df.loc[1]

# %%
schema_df

# %%
schema_df = pd.read_csv('ss24/data/survey_results_schema.csv', index_col='qname')

# %%
schema_df

# %%
schema_df.loc['Age']

# %%
schema_df.loc['Employment', 'question']

# %%
schema_df.sort_index() #without affecting data base itself

# %%
schema_df.sort_index(ascending=False)

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df

# %%
df.columns

# %%
high_salary = (df['ConvertedCompYearly'] > 70000)

# %%
df.loc[high_salary]

# %%
df[high_salary]

# %%
df.loc[high_salary, ['Country', 'LearnCode']]

# %%
df.loc[high_salary, ['Country', 'LearnCode']].value_counts()

# %%
countries = ['United States of America','Germany','United Kingdom','India']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country'].value_counts()

# %%
df['LanguageWantToWorkWith']

# %%
filt = df['LanguageWantToWorkWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWantToWorkWith']

# %%
filt

# %%
df.loc[filt] #only get True value back

# %%
df
