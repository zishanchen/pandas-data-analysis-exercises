# %%
import pandas as pd

# %%
es = pd.read_csv("ErstSemester.csv")
es
# Out:
#     Matrikelnummer    Vorname     Nachname  \
# 0           421001    Apricot    Angelfish
# 1           421005      Amber  Grasshopper
# 2           421015  Harlequin       Bobcat
# 3           421018       Jade    Partridge
# 4           421020      Azure      Halibut
# ..             ...        ...          ...
# 79          421464       Pink     Pinniped
# 80          421477     Bronze   Roadrunner
# 81          421481        Tan   Rhinoceros
# 82          421490      Blush     Squirrel
# 83          421497    Apricot    Wolverine
#
#                                     E-Mail Geschlecht  Year        Haus
# 0   apricot.angelfish@hex.uni-hogwarts.com   weiblich     1   Slytherin
# 1   amber.grasshopper@hex.uni-hogwarts.com   weiblich     1  Hufflepuff
# 2    harlequin.bobcat@hex.uni-hogwarts.com   männlich     1   Ravenclaw
# 3      jade.partridge@hex.uni-hogwarts.com   männlich     1  Gryffindor
# 4       azure.halibut@hex.uni-hogwarts.com   männlich     1  Gryffindor
# ...

# %%
es['Geschlecht']
# Out:
# 0     weiblich
# 1     weiblich
# 2     männlich
# 3     männlich
# 4     männlich
#         ...
# 79    männlich
# 80    männlich
# 81    männlich
# 82    weiblich
# 83    weiblich
# Name: Geschlecht, Length: 84, dtype: object

# %%
es['Geschlecht'].value_counts()
# Out:
# Geschlecht
# männlich    48
# weiblich    36
# Name: count, dtype: int64

# %%
es['Geschlecht'].value_counts(normalize=True)
# Out:
# Geschlecht
# männlich    0.571429
# weiblich    0.428571
# Name: proportion, dtype: float64

# %%
ge_grp = es.groupby(['Geschlecht'])

# %%
ge_grp.get_group('weiblich')
# Out:
# /tmp/ipykernel_877/2807781111.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   ge_grp.get_group('weiblich')
#     Matrikelnummer    Vorname     Nachname  \
# 0           421001    Apricot    Angelfish
# 1           421005      Amber  Grasshopper
# 9           421036     Maroon      Antlion
# 10          421038      Amber      Caribou
# 11          421046       Aqua         Goat
# 12          421048    Scarlet      Haddock
# 13          421058  Chocolate          Cod
# 23          421127   Lavender      Haddock
# 24          421129       Cyan    Blackbird
# 27          421141        Tan    Amphibian
# 29          421153     Maroon       Minnow
# 32          421169      Green   Meadowlark
# 35          421198   Amaranth      Firefly
# 36          421209      Green        Viper
# 38          421232       Gold    Barracuda
# ...

# %%
ge_grp.get_group('männlich')
# Out:
# /tmp/ipykernel_877/2392829405.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   ge_grp.get_group('männlich')
#     Matrikelnummer     Vorname     Nachname  \
# 2           421015   Harlequin       Bobcat
# 3           421018        Jade    Partridge
# 4           421020       Azure      Halibut
# 5           421026         Red     Pinniped
# 6           421030     Magenta     Mongoose
# 7           421033      Maroon       Falcon
# 8           421034        Gray          Fox
# 14          421067     Scarlet      Unicorn
# 15          421074     Fuchsia      Warbler
# 16          421077        Rose         Carp
# 17          421088       Olive     Hoverfly
# 18          421090       Coral   Salamander
# 19          421091        Blue    Alligator
# 20          421098        Gold    Blackbird
# ...

# %%
filt = es['Geschlecht']=='männlich'

# %%
es.loc[filt]
# Out:
#     Matrikelnummer     Vorname     Nachname  \
# 2           421015   Harlequin       Bobcat
# 3           421018        Jade    Partridge
# 4           421020       Azure      Halibut
# 5           421026         Red     Pinniped
# 6           421030     Magenta     Mongoose
# 7           421033      Maroon       Falcon
# 8           421034        Gray          Fox
# 14          421067     Scarlet      Unicorn
# 15          421074     Fuchsia      Warbler
# 16          421077        Rose         Carp
# 17          421088       Olive     Hoverfly
# 18          421090       Coral   Salamander
# 19          421091        Blue    Alligator
# 20          421098        Gold    Blackbird
# 21          421108        Jade       Cicada
# 22          421109    Amaranth  Mockingbird
# 25          421130       Green       Bobcat
# 26          421132         Tan         Mink
# 28          421150     Magenta    Swordtail
# 30          421161        Lime    Orangutan
# ...

# %%
es[filt] == ge_grp.get_group('männlich')
# Out:
# /tmp/ipykernel_877/3362682417.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   es[filt] == ge_grp.get_group('männlich')
#     Matrikelnummer  Vorname  Nachname  E-Mail  Geschlecht  Year  Haus
# 2             True     True      True    True        True  True  True
# 3             True     True      True    True        True  True  True
# 4             True     True      True    True        True  True  True
# 5             True     True      True    True        True  True  True
# 6             True     True      True    True        True  True  True
# 7             True     True      True    True        True  True  True
# 8             True     True      True    True        True  True  True
# 14            True     True      True    True        True  True  True
# 15            True     True      True    True        True  True  True
# ...

# %%
es.loc[filt]['Haus'].value_counts()
# Out:
# Haus
# Ravenclaw     18
# Hufflepuff    12
# Gryffindor     9
# Slytherin      9
# Name: count, dtype: int64

# %%
es.loc[filt]['Haus'].value_counts().loc['Ravenclaw']
# Out:
# 18
